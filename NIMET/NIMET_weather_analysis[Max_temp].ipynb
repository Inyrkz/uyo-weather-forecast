# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# load dataset
dataset = pd.read_excel("/content/merge-nimet-dataset.xlsx")
# Set the date column as index
dataset.set_index('DATES', inplace=True)
dataset
# Out:
#             MAX TEMP (0C)  ...  Vapour Pressure 1500Z
# DATES                      ...
# 2010-01-01           32.5  ...                   24.0
# 2010-01-02           34.0  ...                   20.3
# 2010-01-03           33.2  ...                   31.3
# 2010-01-04           32.1  ...                   23.5
# 2010-01-05           32.5  ...                   23.0
# ...                   ...  ...                    ...
# 2017-12-27           32.5  ...                   21.8
# 2017-12-28           32.2  ...                   27.4
# 2017-12-29           32.0  ...                   29.0
# 2017-12-30           31.8  ...                   21.2
# 2017-12-31           32.0  ...                   26.2
#
# [2922 rows x 11 columns]

# %% [markdown]
# # Exploratory Data Analysis

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2922 entries, 2010-01-01 to 2017-12-31
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   MAX TEMP (0C)          2922 non-null   float64
#  1   MIN TEMP  (0C)         2922 non-null   float64
#  2   RAIN (mm)              2922 non-null   float64
#  3   RH% 0600Z              2922 non-null   float64
#  4   RH% 0900Z              2922 non-null   float64
#  5   RH% 1200Z              2922 non-null   float64
#  6   RH% 1500Z              2922 non-null   float64
#  7   Vapour Pressure 0600Z  2922 non-null   float64
#  8   Vapour Pressure 0900Z  2922 non-null   float64
#  9   Vapour Pressure 1200Z  2922 non-null   float64
#  10  Vapour Pressure 1500Z  2922 non-null   float64
# dtypes: float64(11)
# memory usage: 273.9 KB

# %%
dataset.describe()
# Out:
#        MAX TEMP (0C)  ...  Vapour Pressure 1500Z
# count    2922.000000  ...            2922.000000
# mean       30.795517  ...              30.170897
# std         2.558486  ...               3.127726
# min        22.800000  ...               9.300000
# 25%        28.900000  ...              29.370000
# 50%        31.000000  ...              30.600000
# 75%        32.700000  ...              32.000000
# max        38.000000  ...              41.600000
#
# [8 rows x 11 columns]

# %%
dataset.columns
# Out:
# Index(['DATES', 'MAX TEMP (0C)', 'MIN TEMP  (0C)', 'RAIN (mm)', 'RH% 0600Z',
#        'RH% 0900Z', 'RH% 1200Z', 'RH% 1500Z', ' Vapour Pressure 0600Z',
#        ' Vapour Pressure 0900Z', ' Vapour Pressure 1200Z',
#        ' Vapour Pressure 1500Z'],
#       dtype='object')

# %% [markdown]
# ### Boxplots

# %%
# create boxplot
dataset.plot(kind='box', title='Boxplot', rot=90, figsize=(15,15))

# %%
dataset.boxplot(column='MAX TEMP (0C)')

# %%
dataset.boxplot(column='MIN TEMP  (0C)')

# %%
dataset.boxplot(column='RAIN (mm)')

# %%
dataset.boxplot(column='RH% 0600Z')

# %%
dataset.boxplot(column='RH% 0900Z')

# %%
dataset.boxplot(column='RH% 1200Z')

# %%
dataset.boxplot(column='RH% 1500Z')

# %%
dataset.boxplot(column='Vapour Pressure 0600Z')

# %%
dataset.boxplot(column='Vapour Pressure 0900Z')

# %%
dataset.boxplot(column='Vapour Pressure 1200Z')

# %%
dataset.boxplot(column='Vapour Pressure 1500Z')

# %% [markdown]
# ### Histogram

# %%
fig = plt.figure(figsize=(10,10))
sns.histplot(dataset)

# %%
fig = plt.figure(figsize=(10,10))
sns.histplot(dataset[['MAX TEMP (0C)']])

# %%
fig = plt.figure(figsize=(10,10))
sns.histplot(dataset[['MIN TEMP  (0C)']])

# %%
fig = plt.figure(figsize=(10,10))
sns.histplot(dataset[['RAIN (mm)']])

# %%
fig = plt.figure(figsize=(10,10))
sns.histplot(dataset[['RH% 0600Z']])

# %%
fig = plt.figure(figsize=(10,10))
sns.histplot(dataset[['RH% 0900Z']])

# %%
fig = plt.figure(figsize=(10,10))
sns.histplot(dataset[['RH% 1200Z']])

# %%
fig = plt.figure(figsize=(10,10))
sns.histplot(dataset[['RH% 1500Z']])

# %%
fig = plt.figure(figsize=(10,10))
sns.histplot(dataset[['Vapour Pressure 0600Z']])

# %%
fig = plt.figure(figsize=(10,10))
sns.histplot(dataset[['Vapour Pressure 0900Z']])

# %%
fig = plt.figure(figsize=(10,10))
sns.histplot(dataset[['Vapour Pressure 1200Z']])

# %%
fig = plt.figure(figsize=(10,10))
sns.histplot(dataset[['Vapour Pressure 1500Z']])

# %% [markdown]
# ### Time-Series Analysis

# %%
# Function to plot interactive plots using Plotly Express
def interactive_plot(df, column, timestamp, title):
  '''
  df: dataframe, the dataset.
  column: str, name of column you want to plot
  title: str, title of the plot
  timestamp: str, column of the time for the time series data
  '''
  fig = px.line(title=title)
  for i in df[[column]]:
    fig.add_scatter(x=timestamp, y=df[i], name=i)
  fig.show()
              
interactive_plot(dataset, 'MAX TEMP (0C)', dataset.index, 'Max Temp Plot')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="4d94470a-72f5-4683-84ea-68893218b10a" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("4d94470a-72f5-4683-84ea-68893218b10a")) {
#                     Plotly.newPlot(
#                         '4d94470a-72f5-4683-84ea-68893218b10a',
# ...

# %%
interactive_plot(dataset, 'MIN TEMP  (0C)', dataset.index, 'Min Temp Plot')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="78fccbd3-1e1d-4178-b50a-1bf801f44d80" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("78fccbd3-1e1d-4178-b50a-1bf801f44d80")) {
#                     Plotly.newPlot(
#                         '78fccbd3-1e1d-4178-b50a-1bf801f44d80',
# ...

# %%
interactive_plot(dataset, 'RAIN (mm)' , dataset.index, 'RAIN (mm) Plot')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="0dbb70dc-4674-4712-9024-0c5ac1f9c640" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("0dbb70dc-4674-4712-9024-0c5ac1f9c640")) {
#                     Plotly.newPlot(
#                         '0dbb70dc-4674-4712-9024-0c5ac1f9c640',
# ...

# %%
interactive_plot(dataset, 'RH% 0600Z', dataset.index, 'RH% 0600Z Plot')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="97af07cf-faa3-46c9-b23e-e3b8d90f7b81" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("97af07cf-faa3-46c9-b23e-e3b8d90f7b81")) {
#                     Plotly.newPlot(
#                         '97af07cf-faa3-46c9-b23e-e3b8d90f7b81',
# ...

# %%
interactive_plot(dataset, 'RH% 0900Z', dataset.index, 'RH% 0900Z Plot')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="8a49e1fd-6a46-49e5-be2f-330ade035001" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("8a49e1fd-6a46-49e5-be2f-330ade035001")) {
#                     Plotly.newPlot(
#                         '8a49e1fd-6a46-49e5-be2f-330ade035001',
# ...

# %%
interactive_plot(dataset, 'RH% 1200Z', dataset.index, 'RH% 1200Z Plot')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="68f0fd88-5a5b-4a38-bb82-4fdfe3f8de24" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("68f0fd88-5a5b-4a38-bb82-4fdfe3f8de24")) {
#                     Plotly.newPlot(
#                         '68f0fd88-5a5b-4a38-bb82-4fdfe3f8de24',
# ...

# %%
interactive_plot(dataset, 'RH% 1500Z', dataset.index, 'RH% 1500Z Plot')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="0cbe424b-a9b1-4302-96fe-8db59a641155" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("0cbe424b-a9b1-4302-96fe-8db59a641155")) {
#                     Plotly.newPlot(
#                         '0cbe424b-a9b1-4302-96fe-8db59a641155',
# ...

# %%
interactive_plot(dataset, 'Vapour Pressure 0600Z', dataset.index, 'Vapour Pressure 0600Z Plot')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="a33cdb97-018e-4adf-a5d9-4f5b8ff7bb70" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a33cdb97-018e-4adf-a5d9-4f5b8ff7bb70")) {
#                     Plotly.newPlot(
#                         'a33cdb97-018e-4adf-a5d9-4f5b8ff7bb70',
# ...

# %%
interactive_plot(dataset, 'Vapour Pressure 0900Z', dataset.index, 'Vapour Pressure 0900Z Plot')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="47f84155-3cc7-4ad4-8854-38d573f6ec7a" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("47f84155-3cc7-4ad4-8854-38d573f6ec7a")) {
#                     Plotly.newPlot(
#                         '47f84155-3cc7-4ad4-8854-38d573f6ec7a',
# ...

# %%
interactive_plot(dataset, 'Vapour Pressure 1200Z', dataset.index, 'Vapour Pressure 1200Z Plot')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="c1afe976-4973-4dba-9ccf-daf8eb29c289" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("c1afe976-4973-4dba-9ccf-daf8eb29c289")) {
#                     Plotly.newPlot(
#                         'c1afe976-4973-4dba-9ccf-daf8eb29c289',
# ...

# %%
interactive_plot(dataset, 'Vapour Pressure 1500Z', dataset.index, 'Vapour Pressure 1500Z Plot')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="daa171ef-2f6a-40d3-aad2-9e5adbdb7036" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("daa171ef-2f6a-40d3-aad2-9e5adbdb7036")) {
#                     Plotly.newPlot(
#                         'daa171ef-2f6a-40d3-aad2-9e5adbdb7036',
# ...

# %% [markdown]
# # Data Preprocessing

# %%
# Create a new column of the next day Maximum Temperature
dataset['Next MAX TEMP (0C)'] = dataset[['MAX TEMP (0C)']].shift(-1)
# Remove last nan row
dataset = dataset[:-1]
dataset
# Out:
#             MAX TEMP (0C)  ...  Next MAX TEMP (0C)
# DATES                      ...
# 2010-01-01           32.5  ...                34.0
# 2010-01-02           34.0  ...                33.2
# 2010-01-03           33.2  ...                32.1
# 2010-01-04           32.1  ...                32.5
# 2010-01-05           32.5  ...                32.7
# ...                   ...  ...                 ...
# 2017-12-26           31.6  ...                32.5
# 2017-12-27           32.5  ...                32.2
# 2017-12-28           32.2  ...                32.0
# 2017-12-29           32.0  ...                31.8
# 2017-12-30           31.8  ...                32.0
#
# [2921 rows x 12 columns]

# %%
# Pearson's Corrrelation Plot with Seaborn
fig, ax = plt.subplots(figsize=(20,20))  # Sample figsize in inches
sns.heatmap(dataset.corr(method='pearson'), annot=True, linewidths=.5, ax=ax)

# %%
# Pearson's Corrrelation Plot with Seaborn
fig, ax = plt.subplots(figsize=(20,20))  # Sample figsize in inches
sns.heatmap(dataset.corr(method='spearman'), annot=True, linewidths=.5, ax=ax)

# %%
sns.pairplot(dataset, x_vars=['MAX TEMP (0C)', 'MIN TEMP  (0C)', 'RAIN (mm)'],
             y_vars=["Next MAX TEMP (0C)"], height=7, aspect=0.7)

# %%
sns.pairplot(dataset, x_vars=['RH% 0600Z', 'RH% 0900Z', 'RH% 1200Z', 'RH% 1500Z'],
             y_vars=["Next MAX TEMP (0C)"], height=7, aspect=0.7)

# %%
sns.pairplot(dataset, x_vars=['Vapour Pressure 0600Z', 'Vapour Pressure 0900Z', 'Vapour Pressure 1200Z', 'Vapour Pressure 1500Z'],
             y_vars=["Next MAX TEMP (0C)"], height=7, aspect=0.7)

# %%
max_temp_data = dataset[['MAX TEMP (0C)', 'RH% 1200Z', 'RH% 1500Z', 'Next MAX TEMP (0C)']]
max_temp_data
# Out:
#             MAX TEMP (0C)  RH% 1200Z  RH% 1500Z  Next MAX TEMP (0C)
# DATES
# 2010-01-01           32.5       61.0       52.0                34.0
# 2010-01-02           34.0       55.0       40.0                33.2
# 2010-01-03           33.2       58.0       42.0                32.1
# 2010-01-04           32.1       61.0       49.0                32.5
# 2010-01-05           32.5       58.0       47.0                32.7
# ...                   ...        ...        ...                 ...
# 2017-12-26           31.6       53.0       54.0                32.5
# 2017-12-27           32.5       59.0       46.0                32.2
# 2017-12-28           32.2       58.0       58.0                32.0
# 2017-12-29           32.0       58.0       61.0                31.8
# 2017-12-30           31.8       62.0       46.0                32.0
#
# [2921 rows x 4 columns]

# %%
# Feature Scaling
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaled_max_temp_data = scaler.fit_transform(max_temp_data)

print("Mean of each column", scaler.mean_)
print("Variance of each column", scaler.var_)
scaled_max_temp_data
# Out:
# Mean of each column [30.79510442 73.94573776 73.55621363 30.79493324]
# Variance of each column [  6.54535433 174.27067766 196.007535     6.54485622]
# array([[ 0.66639419, -0.98065138, -1.53969995,  1.25281523],
#        [ 1.25270065, -1.43515683, -2.39682633,  0.94010655],
#        [ 0.94000388, -1.20790411, -2.25397193,  0.51013212],
#        ...,
#        [ 0.5491329 , -1.20790411, -1.11113676,  0.47104354],
#        [ 0.47095871, -1.20790411, -0.89685516,  0.39286637],
#        [ 0.39278451, -0.90490048, -1.96826314,  0.47104354]])

# %%
# Create Matrix of Features and target variable without scaling**
X = scaled_max_temp_data[:, :-1]
y = scaled_max_temp_data[:, -1]
print("Matrix of features", X, sep='\n')
print("--------------------------------------------------")
print("Target Variable", y, sep='\n')
print("--------------------------------------------------")
print("Shape of the Matrix of features", X.shape, sep='\n')
print("Shape of the target variable", y.shape, sep='\n')
# Out:
# Matrix of features
# [[ 0.66639419 -0.98065138 -1.53969995]
#  [ 1.25270065 -1.43515683 -2.39682633]
#  [ 0.94000388 -1.20790411 -2.25397193]
#  ...
#  [ 0.5491329  -1.20790411 -1.11113676]
#  [ 0.47095871 -1.20790411 -0.89685516]
#  [ 0.39278451 -0.90490048 -1.96826314]]
# --------------------------------------------------
# Target Variable
# [1.25281523 0.94010655 0.51013212 ... 0.47104354 0.39286637 0.47104354]
# --------------------------------------------------
# Shape of the Matrix of features
# (2921, 3)
# Shape of the target variable
# (2921,)

# %%
# Splitting Dataset into Training and Validation Set
from sklearn.model_selection import train_test_split
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.25,
                                                  shuffle=False)

# %%
# Define a data plotting function
def show_plot(data, title):
  plt.figure(figsize=(13, 5))
  plt.plot(data, linewidth=3)
  plt.title(title)
  plt.legend(['MAX TEMP (0C)', 'RH% 1200Z', 'RH% 1500Z'])
  plt.grid()

show_plot(X_train, "Training Data")
show_plot(X_val, "Testing Data")

# %% [markdown]
# ## Ridge Regression

# %%
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import Ridge

# fit model to training data
ridge_model = Ridge(alpha=0.5)
ridge_model.fit(X_train, y_train)

# Evaluate of Validation Data
y_pred_1 = ridge_model.predict(X_val)
print("R Squared on Validation Set: ", ridge_model.score(X_val, y_val))
print("RMSE of Ridge Regressor: ", np.sqrt(mean_squared_error(y_val, y_pred_1)))
# Out:
# R Squared on Validation Set:  0.5136808301769847
# RMSE of Ridge Regressor:  0.7360861262239794

# %%
from math import sqrt

# Make Predictions on the entire dataset
y_pred = ridge_model.predict(X)
print("Model Prediction on entire dataset", y_pred)

# Inverse transform y and y_pred
# get the inverse transform of y (the next temp value)
original_y = scaler.inverse_transform(scaled_max_temp_data)[:, -1]
print("Original y", original_y)
# Manually calculate the Inverse transform the model prediction
unscaled_y_pred = (y_pred * sqrt(scaler.var_[-1])) + scaler.mean_[-1]
print("Unstandardized y_pred", unscaled_y_pred)

# Create a dataframe of the actual and predicted values for visualization
df_prediction = pd.DataFrame()
df_prediction["Actual"] = original_y
df_prediction["Prediction"] = unscaled_y_pred
df_prediction.set_index(dataset.index, inplace=True)
print(df_prediction.head(15))

# Function to plot interactive plots using Plotly Express
def interactive_plot2(df, title):
  fig = px.line(title=title)
  for i in df.columns:
    fig.add_scatter(x=df.index, y=df[i], name=i)
  fig.show()

# Plot the results
interactive_plot2(df_prediction, "Original vs. Predictions (Ridge)")
# Out:
# Model Prediction on entire dataset [0.63619217 1.11062755 0.92336859 ... 0.48687985 0.40257307 0.58801304]
# Original y [34.  33.2 32.1 ... 32.  31.8 32. ]
# Unstandardized y_pred [32.42249837 33.63624244 33.15717941 ... 32.0405139  31.82483256
#  32.29924209]
#             Actual  Prediction
# DATES
# 2010-01-01    34.0   32.422498
# 2010-01-02    33.2   33.636242
# 2010-01-03    32.1   33.157179
# 2010-01-04    32.5   32.335465
# 2010-01-05    32.7   32.612718
# 2010-01-06    33.5   32.714339
# 2010-01-07    33.6   33.039651
# 2010-01-08    33.5   33.204522
# 2010-01-09    33.0   32.467917
# 2010-01-10    34.5   32.329357
# 2010-01-11    35.0   33.393289
# 2010-01-12    33.6   33.877252
# 2010-01-13    31.2   32.863415
# 2010-01-14    33.7   31.115501
# 2010-01-15    32.4   32.913868
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
# ...

# %% [markdown]
# ## Lasso Regression

# %%
from sklearn.linear_model import Lasso

# fit model to training data
lasso_model = Lasso(alpha=0.0005)
lasso_model.fit(X_train, y_train)

# Evaluate of Validation Data
y_pred_2 = lasso_model.predict(X_val)
print("R Squared Lasso Regressor: ", lasso_model.score(X_val, y_val))
print("RMSE of Lasso Regressor: ", np.sqrt(mean_squared_error(y_val, y_pred_2)))
# Out:
# R Squared Lasso Regressor:  0.5136013597208373
# RMSE of Lasso Regressor:  0.7361462664716353

# %%
# Make Predictions on the entire dataset
y_pred = lasso_model.predict(X)
print("Model Prediction on entire dataset", y_pred)

# Inverse transform y and y_pred
# get the inverse transform of y (the next temp value)
original_y = scaler.inverse_transform(scaled_max_temp_data)[:, -1]
print("Original y", original_y)
# Manually calculate the Inverse transform the model prediction
unscaled_y_pred = (y_pred * sqrt(scaler.var_[-1])) + scaler.mean_[-1]
print("Unstandardized y_pred", unscaled_y_pred)

# Create a dataframe of the actual and predicted values for visualization
df_prediction = pd.DataFrame()
df_prediction["Actual"] = original_y
df_prediction["Prediction"] = unscaled_y_pred
df_prediction.set_index(dataset.index, inplace=True)
print(df_prediction.head(15))

# Plot the results
interactive_plot2(df_prediction, "Original vs. Predictions (Lasso)")
# Out:
# Model Prediction on entire dataset [0.63529151 1.1088931  0.92168271 ... 0.48708081 0.40313212 0.5866353 ]
# Original y [34.  33.2 32.1 ... 32.  31.8 32. ]
# Unstandardized y_pred [32.4201942  33.63180522 33.15286643 ... 32.04102802 31.82626278
#  32.29571743]
#             Actual  Prediction
# DATES
# 2010-01-01    34.0   32.420194
# 2010-01-02    33.2   33.631805
# 2010-01-03    32.1   33.152866
# 2010-01-04    32.5   32.332774
# 2010-01-05    32.7   32.610255
# 2010-01-06    33.5   32.710984
# 2010-01-07    33.6   33.037874
# 2010-01-08    33.5   33.202275
# 2010-01-09    33.0   32.467691
# 2010-01-10    34.5   32.329906
# 2010-01-11    35.0   33.389468
# 2010-01-12    33.6   33.869363
# 2010-01-13    31.2   32.860165
# 2010-01-14    33.7   31.119251
# 2010-01-15    32.4   32.910529
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
# ...

# %% [markdown]
# ## Decision Tree Regression

# %%
from sklearn.tree import DecisionTreeRegressor

# fit model to training data
dt_model = DecisionTreeRegressor(max_leaf_nodes=25,
                                 random_state=1)
dt_model.fit(X_train, y_train)

# Evaluate of Validation Data
y_pred_4 = dt_model.predict(X_val)
print("R Squared Decision Tree Regressor: ", dt_model.score(X_val, y_val))
print("RMSE of Decision Tree Regressor: ", np.sqrt(mean_squared_error(y_val, y_pred_4)))
# Out:
# R Squared Decision Tree Regressor:  0.488979911911155
# RMSE of Decision Tree Regressor:  0.754548089733797

# %%
# Make Predictions on the entire dataset
y_pred = dt_model.predict(X)
print("Model Prediction on entire dataset", y_pred)

# Inverse transform y and y_pred
# get the inverse transform of y (the next temp value)
original_y = scaler.inverse_transform(scaled_max_temp_data)[:, -1]
print("Original y", original_y)
# Manually calculate the Inverse transform the model prediction
unscaled_y_pred = (y_pred * sqrt(scaler.var_[-1])) + scaler.mean_[-1]
print("Unstandardized y_pred", unscaled_y_pred)

# Create a dataframe of the actual and predicted values for visualization
df_prediction = pd.DataFrame()
df_prediction["Actual"] = original_y
df_prediction["Prediction"] = unscaled_y_pred
df_prediction.set_index(dataset.index, inplace=True)
print(df_prediction.head(15))

# Plot the results
interactive_plot2(df_prediction, "Original vs. Predictions (Decision Tree)")
# Out:
# Model Prediction on entire dataset [0.62487603 0.83077182 0.62487603 ... 0.62487603 0.40438722 0.40438722]
# Original y [34.  33.2 32.1 ... 32.  31.8 32. ]
# Unstandardized y_pred [32.39354839 32.92028986 32.39354839 ... 32.39354839 31.82947368
#  31.82947368]
#             Actual  Prediction
# DATES
# 2010-01-01    34.0   32.393548
# 2010-01-02    33.2   32.920290
# 2010-01-03    32.1   32.393548
# 2010-01-04    32.5   32.393548
# 2010-01-05    32.7   32.393548
# 2010-01-06    33.5   32.393548
# 2010-01-07    33.6   32.920290
# 2010-01-08    33.5   32.920290
# 2010-01-09    33.0   32.920290
# 2010-01-10    34.5   32.393548
# 2010-01-11    35.0   33.381967
# 2010-01-12    33.6   33.381967
# 2010-01-13    31.2   32.920290
# 2010-01-14    33.7   31.829474
# 2010-01-15    32.4   32.920290
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
# ...

# %% [markdown]
# ## XGBoost Regressor

# %%
from xgboost import XGBRegressor

# check for the best number of n_estimators
xgboost_model = XGBRegressor(n_estimators=1000, learning_rate=0.01, n_jobs=-1)
xgboost_model.fit(X_train, y_train,
                  early_stopping_rounds=20,
                  eval_set=[(X_val, y_val)],
                  verbose=True)
# Out:
# [16:39:07] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:1.10211
# Will train until validation_0-rmse hasn't improved in 20 rounds.
# [1]	validation_0-rmse:1.09608
# [2]	validation_0-rmse:1.09017
# [3]	validation_0-rmse:1.08433
# [4]	validation_0-rmse:1.07861
# [5]	validation_0-rmse:1.07294
# [6]	validation_0-rmse:1.06739
# [7]	validation_0-rmse:1.06189
# [8]	validation_0-rmse:1.0565
# [9]	validation_0-rmse:1.0512
# [10]	validation_0-rmse:1.04599
# [11]	validation_0-rmse:1.04087
# [12]	validation_0-rmse:1.03579
# [13]	validation_0-rmse:1.03082
# [14]	validation_0-rmse:1.02587
# [15]	validation_0-rmse:1.02102
# [16]	validation_0-rmse:1.01627
# [17]	validation_0-rmse:1.0116
# [18]	validation_0-rmse:1.00697
# [19]	validation_0-rmse:1.00244
# [20]	validation_0-rmse:0.997925
# [21]	validation_0-rmse:0.993484
# [22]	validation_0-rmse:0.989083
# [23]	validation_0-rmse:0.98477
# ...

# %%
# fit model to training data
from xgboost import XGBRegressor
xgboost_model = XGBRegressor(n_estimators=316, learning_rate=0.01)
xgboost_model.fit(X_train, y_train)

# Evaluate of Validation Data
y_pred_5 = xgboost_model.predict(X_val)
print("R Squared XGBoost Regressor: ", xgboost_model.score(X_val, y_val))
print("RMSE of XGBoost Regressor: ", np.sqrt(mean_squared_error(y_val, y_pred_5)))
# Out:
# [16:39:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# R Squared XGBoost Regressor:  0.5136097655684366
# RMSE of XGBoost Regressor:  0.7361399054751714

# %%
# Make Predictions on the entire dataset
y_pred = xgboost_model.predict(X)
print("Model Prediction on entire dataset", y_pred)

# Inverse transform y and y_pred
# get the inverse transform of y (the next temp value)
original_y = scaler.inverse_transform(scaled_max_temp_data)[:, -1]
print("Original y", original_y)
# Manually calculate the Inverse transform the model prediction
unscaled_y_pred = (y_pred * sqrt(scaler.var_[-1])) + scaler.mean_[-1]
print("Unstandardized y_pred", unscaled_y_pred)

# Create a dataframe of the actual and predicted values for visualization
df_prediction = pd.DataFrame()
df_prediction["Actual"] = original_y
df_prediction["Prediction"] = unscaled_y_pred
df_prediction.set_index(dataset.index, inplace=True)
print(df_prediction.head(15))

# Plot the results
interactive_plot2(df_prediction, "Original vs. Predictions (XGBoost)")
# Out:
# Model Prediction on entire dataset [0.60439104 0.9695251  0.7747076  ... 0.66493726 0.66493726 0.5228499 ]
# Original y [34.  33.2 32.1 ... 32.  31.8 32. ]
# Unstandardized y_pred [32.34114  33.27526  32.776863 ... 32.496037 32.496037 32.132538]
#             Actual  Prediction
# DATES
# 2010-01-01    34.0   32.341141
# 2010-01-02    33.2   33.275261
# 2010-01-03    32.1   32.776863
# 2010-01-04    32.5   32.341141
# 2010-01-05    32.7   32.526970
# 2010-01-06    33.5   32.336906
# 2010-01-07    33.6   33.146439
# 2010-01-08    33.5   33.146439
# 2010-01-09    33.0   32.736443
# 2010-01-10    34.5   32.745926
# 2010-01-11    35.0   33.607929
# 2010-01-12    33.6   33.436737
# 2010-01-13    31.2   32.816696
# 2010-01-14    33.7   31.515232
# 2010-01-15    32.4   32.816696
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
# ...
